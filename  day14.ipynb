# %% [markdown]
# ## tuple
#         ## immutable and like list

# %%
x=(10,20,30)
print(x[0:2])
# Out:
# (10, 20)

# %%
print(x.count(10))
print(x.index(30))
# Out:
# 1
# 2

# %% [markdown]
# ## difference b/w list and tuple
#             ## list is slow than tuple

# %%
x=(10,20,30,40)
x=x+(50,60)

# %%
x
# Out:
# (10, 20, 30, 40, 50, 60)

# %% [markdown]
# ## dictionary
#         ## it is a type of datatype
#           ## data based on key:value pair
#           ## time complexity o(n)
#           # key is unique idenidfer
#           # value_>data
#           # value can be  duplicate
#           # {}
#           # {key:value , key2:value}
#           # no index position
#           # key should be of imutable datatype

# %%
d={100:"aman",101:"tushar"}
print(d[100])
print(type(d))
d[102]="golu"
print(d)
# Out:
# aman
# <class 'dict'>
# {100: 'aman', 101: 'tushar', 102: 'golu'}

# %%
d[102]='gotiya'

# %%
d
# Out:
# {100: 'aman', 101: 'tushar', 102: 'gotiya'}

# %%
out=d.pop(100)

# %%
d
# Out:
# {101: 'tushar', 102: 'gotiya'}

# %%
print(d,out)
# Out:
# {101: 'tushar', 102: 'gotiya'} aman

# %%
out=d.popitem()

# %%
print(d,out)
# Out:
# {101: 'tushar'} (102, 'gotiya')

# %%
d.keys()
# Out:
# dict_keys([101])

# %%
d.values()
# Out:
# dict_values(['tushar'])

# %%
d.items()
# Out:
# dict_items([(101, 'tushar')])

# %%
d.update({100:'gotiya',101:'man'}) ## use to update multiple values

# %%
d
# Out:
# {101: 'man', 100: 'gotiya'}

# %%
d.update({105:100})

# %%
d
# Out:
# {101: 'man', 100: 'gotiya', 105: 100}

# %%
d=d[105]+90

# %%
d
# Out:
# 190

# %%
d={}
for i in range(10,16):
    d[i]=1
print(d)
# Out:
# {10: 1, 11: 1, 12: 1, 13: 1, 14: 1, 15: 1}

# %%
d={}
for i in range(10,16):
    if(i%2==0):
        d[i]=1
print(d)
# Out:
# {10: 1, 12: 1, 14: 1}

# %%
d={}
s="hey ura"
for i in s:
    if(i=='a' or i=='e' or i=='o' or i=='u'):
        d[i]=1
print(d)
# Out:
# {'e': 1, 'u': 1, 'a': 1}

# %%
d={}
s="hey ura"
count=0
for i in s:
    if(i=='a' or i=='e' or i=='o' or i=='u'):
        d[i]=1
print(d)
# Out:
# {'e': 1, 'u': 1, 'a': 1}

# %%
x={"salary":100}
if ("salary"in x):
    x["salary"]=x["salary"]+10
else:
    x["salary"]=10
print(x)
# Out:
# {'salary': 110}

# %%
d={}
s="heyeerurae"
for i in s:
    if i in "aeiou":
        
        if i in d:
           d[i]= d[i]+1
        else:
            d[i]=1
print(d)
# Out:
# {'e': 4, 'u': 1, 'a': 1}

# %%
## wap loop from 1 to 100
  #
